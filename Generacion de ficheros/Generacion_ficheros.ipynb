# %% [markdown]
# # Generación de ficheros de metadatos y lectura de formatos en python/R

# %% [markdown]
# ### Iker Aguirre Otaegui
#
# 27 de noviembre de 2020

# %% [markdown]
# El siguiente trabajo contiene información sobre fuentes de metainformación que contengan la estructura de los datos con los que trabajamos en generación de librerías de procesamiento de datos. En este caso, me centraré más en Yaml y Json. Incluyo sendas y funciones para la lectura de estos archivos.

# %% [markdown]
# # 1. YAML

# %%
import yaml

# %% [markdown]
# En el primer ejemplo de Yaml, creo un archivo en este formato:

# %%
players = [{'name': 'Eden', 'email': 'eden7@gmail.com', 'age': '31','country': 'Belgium'},
        {'name': 'Lucas', 'email': 'cafucas.rm@gmail.com', 'age': '29','country': 'Spain'},
        {'name': 'Francisco', 'email': 'isco@gmail.com', 'age': '28','country': 'Spain'}]

# %%
def read_yaml_file2(filename):
    with open(filename, 'r') as stream:
        y = yaml_load(stream)
        print(y)

# %%
read_yaml_file("players.yaml")
# Out:
# [{'age': '31', 'country': 'Spain', 'email': 'juan64@gmail.com', 'name': 'Juan'}, {'age': '22', 'country': 'Spain', 'email': 'maria_gonzalez@gmail.com', 'name': 'Maria'}, {'age': '28', 'country': 'Spain', 'email': 'isco22@gmail.com', 'name': 'Francisco'}]

# %% [markdown]
# En el siguiente ejemplo, leo un archivo en formato Yaml.

# %%
with open('/Users/ikeraguirreotaegui/Desktop/bcc-kaggle.yaml') as file:
    file = yaml.full_load(file)

# %%
file
# Out:
# {'train': '/kaggle/working/blood-cell-count-and-typesdetection/images/images/train',
#  'val': '/kaggle/working/blood-cell-count-and-typesdetection/images/images/valid',
#  'nc': 3,
#  'names': ['Platelets', 'RBC', 'WBC']}

# %% [markdown]
# # 2. JSON

# %%
import json

# %% [markdown]
# Al igual que en el caso de Yaml, creamos un archivo.

# %%
players = [{'name': 'Eden', 'email': 'eden7@gmail.com', 'age': '31','country': 'Belgium'},
        {'name': 'Lucas', 'email': 'cafucas.rm@gmail.com', 'age': '29','country': 'Spain'},
        {'name': 'Francisco', 'email': 'isco@gmail.com', 'age': '28','country': 'Spain'}]

# %%
json_players = json.dumps(players)

# %%
print(json_players)
# Out:
# [{"name": "Eden", "email": "eden7@gmail.com", "age": "31", "country": "Belgium"}, {"name": "Lucas", "email": "cafucas.rm@gmail.com", "age": "29", "country": "Spain"}, {"name": "Francisco", "email": "isco@gmail.com", "age": "28", "country": "Spain"}]

# %% [markdown]
# Una vez más, leemos un archivo formato Json.

# %%
with open('/Users/ikeraguirreotaegui/Desktop/iris.json') as f:
  data = json.load(f)

# %%
data
# Out:
# [{'sepalLength': 5.1,
#   'sepalWidth': 3.5,
#   'petalLength': 1.4,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 4.9,
#   'sepalWidth': 3.0,
#   'petalLength': 1.4,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 4.7,
#   'sepalWidth': 3.2,
#   'petalLength': 1.3,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 4.6,
#   'sepalWidth': 3.1,
#   'petalLength': 1.5,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 5.0,
#   'sepalWidth': 3.6,
#   'petalLength': 1.4,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 5.4,
#   'sepalWidth': 3.9,
#   'petalLength': 1.7,
#   'petalWidth': 0.4,
#   'species': 'setosa'},
#  {'sepalLength': 4.6,
#   'sepalWidth': 3.4,
#   'petalLength': 1.4,
#   'petalWidth': 0.3,
#   'species': 'setosa'},
#  {'sepalLength': 5.0,
#   'sepalWidth': 3.4,
#   'petalLength': 1.5,
#   'petalWidth': 0.2,
#   'species': 'setosa'},
#  {'sepalLength': 4.4,
# ...

# %% [markdown]
# # 3. ¿Se pueden leer con Spark?

# %% [markdown]
# Si. En la bibliografía incluyo una entrada de stackoverflow en la que se explica detalladamente como hacerlo con Yaml.

# %% [markdown]
# # 4. ¿Qué tipo de bases de datos No SQL usa estructuras de datos similares?

# %% [markdown]
# 1. Riak KV
# 2. Redis
# 3. MongoDB
# 4. CoucheBase
# 5. MarkLogic
# 6. Cassandra
# 7. Hbase

# %% [markdown]
# # 5. Bibliografia

# %% [markdown]
# https://stackabuse.com/reading-and-writing-yaml-to-a-file-in-python/
#
# https://stackabuse.com/reading-and-writing-json-to-a-file-in-python/
#
# https://bosonit.com/tipos-de-bases-de-datos-nosql-2-clave-valor-documentales-y-columnares/
#
# https://stackoverflow.com/questions/58806113/how-to-parse-a-yaml-with-spark-scala
